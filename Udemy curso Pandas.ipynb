# %%
import pandas as pd

# %%
df = pd.read_csv("test.csv", index_col=0, header = 0)

# %%
df
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
# ...            ...    ...    ...         ...           ...
# 1006036  P00118942      F  26-35          15             B
# 1006036  P00254642      F  26-35          15             B
# 1006036  P00031842      F  26-35          15             B
# 1006037  P00124742      F  46-50           1             C
# 1006039  P00316642      F  46-50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# ...

# %%
df = pd.read_csv("test.csv")

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  2.335990e+05  233599.000000   233599.000000       233599.000000
# mean   1.003029e+06       8.085407        0.410070            5.276542
# std    1.726505e+03       6.521146        0.491847            3.736380
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001527e+06       2.000000        0.000000            1.000000
# 50%    1.003070e+06       7.000000        0.000000            5.000000
# 75%    1.004477e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3
# count       161255.000000        71037.000000
# mean             9.849586           12.669454
# std              5.094943            4.125944
# min              2.000000            3.000000
# 25%              5.000000            9.000000
# 50%              9.000000           14.000000
# ...

# %%
df = pd.read_csv("test.csv", index_col=0, header = 0)

# %%
df
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
# ...            ...    ...    ...         ...           ...
# 1006036  P00118942      F  26-35          15             B
# 1006036  P00254642      F  26-35          15             B
# 1006036  P00031842      F  26-35          15             B
# 1006037  P00124742      F  46-50           1             C
# 1006039  P00316642      F  46-50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# ...

# %%
df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  233599.000000   233599.000000       233599.000000       161255.000000
# mean        8.085407        0.410070            5.276542            9.849586
# std         6.521146        0.491847            3.736380            5.094943
# min         0.000000        0.000000            1.000000            2.000000
# 25%         2.000000        0.000000            1.000000            5.000000
# 50%         7.000000        0.000000            5.000000            9.000000
# 75%        14.000000        1.000000            8.000000           15.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count        71037.000000
# mean            12.669454
# std              4.125944
# min              3.000000
# 25%              9.000000
# 50%             14.000000
# 75%             16.000000
# max             18.000000

# %%
l = [12,9,8,]

s1= pd.Series(l)

print(s1)
# Out:
# 0    12
# 1     9
# 2     8
# dtype: int64

# %%
l = [12,9,8,]

s1= pd.Series(l, index =["a","b","c"])

print(s1)
# Out:
# a    12
# b     9
# c     8
# dtype: int64

# %%
d = {"a":12,"b":13,"c":10}

s1= pd.Series(d)

print(s1)
# Out:
# a    12
# b    13
# c    10
# dtype: int64

# %%
#Creating a dataframe
classes =  pd.Series(["Mathematics","Chemestry","Phsics","History","Geography","German"])

grades = pd.Series([90,54,77,22,25])

df1= pd.DataFrame({"Subjects": classes, "grades":grades})

# %%
df1
# Out:
#       Subjects  grades
# 0  Mathematics    90.0
# 1    Chemestry    54.0
# 2       Phsics    77.0
# 3      History    22.0
# 4    Geography    25.0
# 5       German     NaN

# %%
classes = ["Mathematics","Chemestry","Phsics","History","Geography","German"]

grades = [90,54,77,22,25]

df1= pd.DataFrame([classes, grades])

# %%
df1
# Out:
#              0          1       2        3          4       5
# 0  Mathematics  Chemestry  Phsics  History  Geography  German
# 1           90         54      77       22         25    None

# %%
df1.tail()
# Out:
#              0          1       2        3          4       5
# 0  Mathematics  Chemestry  Phsics  History  Geography  German
# 1           90         54      77       22         25    None

# %%
df = pd.read_csv("test.csv", index_col=0, header = 0)

# %%
df
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
# ...            ...    ...    ...         ...           ...
# 1006036  P00118942      F  26-35          15             B
# 1006036  P00254642      F  26-35          15             B
# 1006036  P00031842      F  26-35          15             B
# 1006037  P00124742      F  46-50           1             C
# 1006039  P00316642      F  46-50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# ...

# %%
new_df = df.dropna()

# %%
new_df.describe()
# Out:
#          Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  71037.000000    71037.000000        71037.000000        71037.000000
# mean       8.219801        0.402002            2.725185            6.882287
# std        6.482756        0.490306            2.564070            4.510544
# min        0.000000        0.000000            1.000000            2.000000
# 25%        3.000000        0.000000            1.000000            2.000000
# 50%        7.000000        0.000000            1.000000            6.000000
# 75%       14.000000        1.000000            4.000000           10.000000
# max       20.000000        1.000000           15.000000           16.000000
#
#        Product_Category_3
# count        71037.000000
# mean            12.669454
# std              4.125944
# min              3.000000
# 25%              9.000000
# 50%             14.000000
# 75%             16.000000
# max             18.000000

# %%
df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  233599.000000   233599.000000       233599.000000       161255.000000
# mean        8.085407        0.410070            5.276542            9.849586
# std         6.521146        0.491847            3.736380            5.094943
# min         0.000000        0.000000            1.000000            2.000000
# 25%         2.000000        0.000000            1.000000            5.000000
# 50%         7.000000        0.000000            5.000000            9.000000
# 75%        14.000000        1.000000            8.000000           15.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count        71037.000000
# mean            12.669454
# std              4.125944
# min              3.000000
# 25%              9.000000
# 50%             14.000000
# 75%             16.000000
# max             18.000000

# %%
new_df = df.fillna(0)

# %%
new_df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# 1000010                         4+               1                   5
# 1000010                         4+               1                   4
# 1000011                          1               0                   4
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                 0.0
# 1000009                 5.0                 0.0
# ...

# %%
new_df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# 1000010                         4+               1                   5
# 1000010                         4+               1                   4
# 1000011                          1               0                   4
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                 0.0
# 1000009                 5.0                 0.0
# ...

# %%
mean =  df["Product_Category_3"].mean()

# %%
new_df = df.fillna(mean)

# %%
new_df
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
# ...            ...    ...    ...         ...           ...
# 1006036  P00118942      F  26-35          15             B
# 1006036  P00254642      F  26-35          15             B
# 1006036  P00031842      F  26-35          15             B
# 1006037  P00124742      F  46-50           1             C
# 1006039  P00316642      F  46-50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# ...

# %%
median =  df["Product_Category_3"].median()

# %%
median
# Out:
# 14.0

# %%
new_df = df.fillna(median)

# %%
new_df
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
# ...            ...    ...    ...         ...           ...
# 1006036  P00118942      F  26-35          15             B
# 1006036  P00254642      F  26-35          15             B
# 1006036  P00031842      F  26-35          15             B
# 1006037  P00124742      F  46-50           1             C
# 1006039  P00316642      F  46-50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# ...

# %%
df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# 1000010                         4+               1                   5
# 1000010                         4+               1                   4
# 1000011                          1               0                   4
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                 NaN
# 1000009                 5.0                 NaN
# ...

# %%
import numpy as np

# %%
df["Product_Category_3"].replace(np.nan, 0, inplace = True)
df["Product_Category_2"].replace(np.nan, 0, inplace = True)
df["Product_Category_1"].replace(np.nan, 0, inplace = True)

# %%
df["Stay_In_Current_City_Years"].replace('4+','4', inplace = True)

# %%
df
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
# ...            ...    ...    ...         ...           ...
# 1006036  P00118942      F  26-35          15             B
# 1006036  P00254642      F  26-35          15             B
# 1006036  P00031842      F  26-35          15             B
# 1006037  P00124742      F  46-50           1             C
# 1006039  P00316642      F  46-50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# ...

# %%
df["Age"].unique()
# Out:
# array(['46-50', '26-35', '36-45', '18-25', '51-55', '55+', '0-17'],
#       dtype=object)

# %%
df["Age"].replace(['46-50', '26-35', '36-45', '18-25', '51-55', '55+', '0-17'],['50','35','45','25','55','60','17'], inplace = True)

# %%
df
# Out:
#         Product_ID Gender Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  50           7             B
# 1000009  P00113442      M  35          17             C
# 1000010  P00288442      F  45           1             B
# 1000010  P00145342      F  45           1             B
# 1000011  P00053842      F  35           1             C
# ...            ...    ...  ..         ...           ...
# 1006036  P00118942      F  35          15             B
# 1006036  P00254642      F  35          15             B
# 1006036  P00031842      F  35          15             B
# 1006037  P00124742      F  50           1             C
# 1006039  P00316642      F  50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# ...

# %%
df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  233599.000000   233599.000000       233599.000000       233599.000000
# mean        8.085407        0.410070            5.276542            6.799237
# std         6.521146        0.491847            3.736380            6.217668
# min         0.000000        0.000000            1.000000            0.000000
# 25%         2.000000        0.000000            1.000000            0.000000
# 50%         7.000000        0.000000            5.000000            5.000000
# 75%        14.000000        1.000000            8.000000           14.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count       233599.000000
# mean             3.852756
# std              6.256634
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              8.000000
# max             18.000000

# %%
print(df.dtypes)
# Out:
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# dtype: object

# %%
pd.to_numeric(df['Age'])
# Out:
# User_ID
# 1000004    50
# 1000009    35
# 1000010    45
# 1000010    45
# 1000011    35
#            ..
# 1006036    35
# 1006036    35
# 1006036    35
# 1006037    50
# 1006039    50
# Name: Age, Length: 233599, dtype: int64

# %%
df["Age"] = df["Age"].astype('int')

# %%
print(df.dtypes)
# Out:
# Product_ID                     object
# Gender                         object
# Age                             int32
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# dtype: object

# %%
print(df.dtypes)
# Out:
# Product_ID                     object
# Gender                         object
# Age                             int32
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# dtype: object

# %%
df.drop_duplicates()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
# ...            ...    ...    ...         ...           ...
# 1006036  P00118942      F  26-35          15             B
# 1006036  P00254642      F  26-35          15             B
# 1006036  P00031842      F  26-35          15             B
# 1006037  P00124742      F  46-50           1             C
# 1006039  P00316642      F  46-50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# ...

# %%
df.drop_duplicates(subset=None, keep='first', inplace=True, ignore_index=False)

# %%
df
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
# ...            ...    ...    ...         ...           ...
# 1006036  P00118942      F  26-35          15             B
# 1006036  P00254642      F  26-35          15             B
# 1006036  P00031842      F  26-35          15             B
# 1006037  P00124742      F  46-50           1             C
# 1006039  P00316642      F  46-50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# ...

# %%
df.corr()
# Out:
#                     Occupation  Marital_Status  Product_Category_1  \
# Occupation            1.000000        0.021872           -0.010465
# Marital_Status        0.021872        1.000000            0.018860
# Product_Category_1   -0.010465        0.018860            1.000000
# Product_Category_2   -0.001685        0.021766            0.540063
# Product_Category_3    0.003838        0.016119            0.225054
#
#                     Product_Category_2  Product_Category_3
# Occupation                   -0.001685            0.003838
# Marital_Status                0.021766            0.016119
# Product_Category_1            0.540063            0.225054
# Product_Category_2            1.000000            0.543417
# Product_Category_3            0.543417            1.000000

# %%
def make_latin_square(n):
    return [[(i+j)%n+1 for i in range(n)] for j in range(n)]

# %%
make_latin_square(4)
# Out:
# [[1, 2, 3, 4], [2, 3, 4, 1], [3, 4, 1, 2], [4, 1, 2, 3]]

# %%
#Explicación:
#El usuario ingresa 5 como valor de n, y luego ingresa la lista de números 10 5 8 3 7. Después de eliminar los duplicados y ordenar la lista en orden ascendente, obtenemos la lista [3, 5, 7, 8, 10]. El segundo elemento más grande de esta lista es 8, que se imprime como resultado.

# %%
n = int(input())
l = list(map(int,input().split()))

l = list(set(l))
l.sort()

print(l[-2])
